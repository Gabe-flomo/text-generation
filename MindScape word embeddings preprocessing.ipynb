# %% [markdown]
# # Preprocessing
# * Convert letters to lowercase
# * convert numbers into words (excluding timestamps)
# * remove punctuation
# * remove white space
# * remove stop words

# %%
import re
import string
import numpy as np 
import pandas as pd
import nltk as nlp
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
import spacy # for Part Of Speech  tagging
import tqdm
import os
import inflect
p = inflect.engine()

# %%
path = r'E:\Documents\My Projects\Text Scraper\data'

# %%
def get_files(path, names_only = False):
    ''' Returns a list of filepaths from a directory'''
    files = list()
    for file in os.listdir(path):
        #print(file)
        # append the fullpath
        if names_only:
            files.append(file)
        else:
            files.append(os.path.join(path,file))
    
    return files

def read_files(filepaths):
    ''' Reads files in a path and returns as a dictionary'''
    text = dict()
    for index, file in enumerate(filepaths):
        with open(file, 'r', encoding = "UTF-8") as data:
            content = data.read()
        
        text[index] = content
        
    print(f'Done! Corpus size: {len(text)} documents')
    return text

# %%
files = get_files(path)

# %%
corpus = read_files(files)
# Out:
# Done! Corpus size: 107 documents

# %%
print(len(corpus[0]))
# Out:
# 81961

# %%
def prnt(value):
    ''' print a number with commas '''
    
    value = str(value)
    value_flipped = list(value[::-1])
#     print(value_flipped)
    pos = list()
    for i in range(3,len(value_flipped)+1,4):
        pos.append(i)
        
    for i in pos:
        value_flipped.insert(i,".")
        
    print("".join(value_flipped[::-1]))
               
total = 0
for index, text in corpus.items():
    total += len(corpus[index])


prnt(total)
# Out:
# 9.085.542

# %%
sample = corpus
print(sample)
# Out:
# 0:00:00 Sean Carroll: Hello, everyone. Welcome to the Mindscape Podcast. I am your host Sean Carroll and if you’re like me, you remember maybe in high school, maybe in college in some psychology course being taught about Abraham Maslow’s hierarchy of needs. There was this pyramid diagram and at the bottom of it, there were your basic physiological needs: Food, shelter, things like that. Then you built up through other higher level psychological needs, until at the top, you reach self-actualization. So today’s guest, Scott Barry Kaufman, is a psychologist who is proposing that we update Maslow’s hierarchy of needs. He’s done two things. 0:00:37 SC: Number one, he’s actually dug into many of the writings that Maslow himself did and learned things like Maslow himself never drew a pyramid and Maslow himself had a lot of ideas that go well beyond the famous hierarchy of needs and the second thing that Scott does is propose an entirely new metaphor based on a different kind of hierarchy. He thinks that the pyramid metaphor is a little bit stationary and it gives you the idea that there’s just something to achieve that would make us once and for all self-actualized. 0:01:08 SC: Scott’s idea is that instead, what we should aim for is not self-actualization but transcendence and the metaphor he uses for this is not a pyramid but a sailboat. There’s the hull of the boat, which has some of your more basic needs and then there’s the sails of the sailboat, which have more dynamic needs and I like this imagery because, as a physicist, as someone who knows about entropy and the arrow of time, in the big picture and elsewhere, I’ve absolutely emphasized that we should think of life as a process, as a series of changes, inevitable changes. Things like happiness, which are very popular, are a little bit overrated because we get the idea that you can just achieve happiness and stay there and life is not like that. 0:01:51 SC: Scott and I talk about different ways of being psychologically healthy, the different needs that he’s identified, the empirical research that he’s used to identify these needs and I push back a little bit because I don’t agree with everything he says but you know what? That’s psychology. We’re not anywhere near done. It’s not a mature field in the way that particle physics or cosmology are. That gives us a little bit of a way to think about ways that we could do better in understanding who we as human beings really are, how we can live our best lives. 0:02:19 SC: I should also mention that Scott has his own podcast called The Psychology Podcast. He was lucky enough to get that name early on, where you can find him talking to a bunch of professional psychologists about these ideas and a whole bunch of related ideas. 0:02:34 SC: Remember, you can support the Mindscape Podcast on Patreon if you go to patreon.com/seanmcarroll or just find a link on the podcast homepage which is preposterousuniverse.com/podcast. Different ways you can support on Patreon: Giving $1 or $2 or whatever per episode and in return, you get ad free versions of the episodes and you also get the ability to ask questions at the monthly Ask Me Anything and we’ve changed the policy, so now the answers to the monthly AMA go public, so everyone can listen to them but if you want to actually ask them and get your question answered, you should join Patreon today. Wit

# %%
def remove_punctuation(text):
    text = re.sub(r'[^\w\s]','',text)
    text = text.replace('\n',"")
    text = text.replace('\t',"")
    return text

def convert_numbers(text, verbose = False):
    # convert corpus into a list so we can look at whole words instead of characters
    text = text.split()
    
    # look at each word    
    for index,word in enumerate(text):
        # handles for money
        if word.startswith('$'):
            if verbose:
                print(f'{text[index]}')
            money = word.split('$')
            #print(f'amount: {money}\n')
            
            # make sures the input text has digits 
            try:
                # hanldes for commas in the number eg. 34,543
                if len(money[1]) > 3:
                    # substitute anythin thats not a digit with whitespace
                    amount = int(re.sub(r'[^0-9]','',money[1]))
                    #print(amount)
                    
                # if the number is less than 1,000
                else:
                    amount = int(money[1])
            except ValueError:
                print(f'{money[1]}. This is not an appropriate value\n')
                continue
            
            # converts the number to text
            in_text = p.number_to_words(amount, andword = '', zero = 'oh') + ' dollars'
            if verbose:
                print(f'Amount in text: {in_text}\n')
                
            text[index] = in_text
        
        # standard case of just coming across a word
        if word.isnumeric():
            
                
            in_text = p.number_to_words(word, andword = '', zero = 'oh') 
            old_word = text[index]
            text[index] = in_text
            
            if verbose:
                print(f'{old_word}')
                print(f'Number in text: {in_text}\n')
            
    # convert the list back into a string
    text = " ".join(text)
    return text
            
            

def lemmeatize(text):
    pass

def stem(text):
    pass

def remove_timestamps(text):
    text = re.sub(r'\d{1}:\d{2}:\d{2}','________',text)
    return text

def tokenize(text):
    pass

def clean(doc, verbose = True):
    import string
    # replace '--' with " "
    doc = doc.replace('--'," ")
    
    # convert numbers into words
    doc = convert_numbers(doc)
    # remove timestamps
    doc = remove_timestamps(doc)
    
    # split into a list (tokens)by whitespace
    tokens = doc.split()
    # remove punctuation
    table = str.maketrans('','',string.punctuation)
    tokens = [word.translate(table) for word in tokens]
    # remove tokens that arent alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # make all lower case
    tokens = [word.lower() for word in tokens]
    # get the sequences also
    seqs = sequences(tokens)
    # vocab
    vocab = sorted(set(tokens))
    
    if verbose:
        print(f'Total Characters: {len(tokens)}')
        print(f'Unique Characters: {len(sorted(set(tokens)))}')
        print(f'Total Sequences: {len(seqs)}')

        
    return tokens, vocab, seqs

def sequences(tokens, length = 50):
    # organize into sequences of tokens
    length += 1
    sequences = list()

    # generate sequences
    # grabs a subset of the text 51 characters at a time
    for index in range(length, len(tokens)):
        # select a sequence of tokens from 0 to 51, then 52 - 103, and so on
        seq = tokens[index - length: index]
        #print(index - length,index)

        # flatten the sequence (convert into a string)
        line = ' '.join(seq)
        # append the sequnce
        sequences.append(line)
    
    return sequences

def save_tokens(tokens, filename, location):
    # join the location and the filename
    path = os.path.join(location,filename)
    with open(path,'w',encoding = 'UTF-8') as file:
        for i in range(len(tokens)):
            if i%20 == 0:
                file.write('\n')
            else:
                file.write(tokens[i]+' ')
        print(f'Tokens saved to: {path}') 
        
def save_seqs(seqs, filename, location):
    
    path = os.path.join(location,filename)
    with open(path,'w',encoding = 'UTF-8') as file:
        data = '\n'.join(seqs)
        file.write(data) 
        
    print(f'Sequences saved to: {path}')
        
def save_all(tokens, vocab, seqs, filenames, location):
    ''' save the tokens, vocab and sequences to a file.
    
    filenames is a list where 
    filename[0] = tokens
    filename[1] = vocab
    filename[2] = sequences
    
    '''
    save_tokens(tokens, filenames[0], location)
    save_tokens(vocab, filenames[1], location)
    save_seqs(seqs, filenames[2],location)
    
    
    
#remove_punctuation(sample)
tokens, vocab, seqs = clean(sample)
names = ['tokens.txt','vocab.txt','seqs.txt']
location = r'E:\Documents\My Projects\Text Generation\data\Mindscape articles'
save_all(tokens, vocab, seqs, names, location)
# Out:
# Total Characters: 604
# Unique Characters: 279
# Total Sequences: 553
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\tokens.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\vocab.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\seqs.txt

# %%
# save each article in the corpus
for index, article in corpus.items():
    print(f'Article {index}')
    # get the tokens, vocab and sequences
    tokens, vocab, seqs = clean(article)
    # change the filename based on index 
    names = [f'tokens_{str(index)}.txt',f'vocab_{str(index)}.txt',f'seqs_{str(index)}.txt']
    location = r'E:\Documents\My Projects\Text Generation\data\Mindscape articles'
    # save everything for this article
    save_all(tokens, vocab, seqs, names, location)
    print()
# Out:
# Article 0
# Total Characters: 13987
# Unique Characters: 1815
# Total Sequences: 13936
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_0.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_0.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_0.txt
#
# Article 1
# Total Characters: 10201
# Unique Characters: 1521
# Total Sequences: 10150
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_1.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_1.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_1.txt
#
# Article 2
# Total Characters: 16602
# Unique Characters: 2079
# Total Sequences: 16551
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_2.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_2.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_2.txt
#
# Article 3
# Total Characters: 16584
# Unique Characters: 1920
# Total Sequences: 16533
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_3.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_3.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_3.txt
#
# Article 4
# Total Characters: 9976
# Unique Characters: 1626
# Total Sequences: 9925
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_4.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_4.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_4.txt
#
# Article 5
# Total Characters: 15476
# Unique Characters: 2350
# Total Sequences: 15425
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_5.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_5.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_5.txt
#
# Article 6
# Total Characters: 5379
# Unique Characters: 1630
# Total Sequences: 5328
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_6.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_6.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_6.txt
#
# Article 7
# Total Characters: 13670
# Unique Characters: 1533
# Total Sequences: 13619
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_7.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_7.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_7.txt
#
# Article 8
# Total Characters: 18364
# Unique Characters: 2206
# Total Sequences: 18313
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_8.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_8.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_59.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_59.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_59.txt
#
# Article 60
# Total Characters: 12516
# Unique Characters: 1658
# Total Sequences: 12465
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_60.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_60.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_60.txt
#
# Article 61
# Total Characters: 11535
# Unique Characters: 1801
# Total Sequences: 11484
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_61.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_61.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_61.txt
#
# Article 62
# 20…. This is not an appropriate value
#
# 50,. This is not an appropriate value
#
# 50,. This is not an appropriate value
#
# Total Characters: 18550
# Unique Characters: 2324
# Total Sequences: 18499
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_62.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_62.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_62.txt
#
# Article 63
# Total Characters: 9791
# Unique Characters: 1642
# Total Sequences: 9740
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_63.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_63.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_63.txt
#
# Article 64
# Total Characters: 13595
# Unique Characters: 1930
# Total Sequences: 13544
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_64.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_64.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_64.txt
#
# Article 65
# Total Characters: 9722
# Unique Characters: 1895
# Total Sequences: 9671
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_65.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_65.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_65.txt
#
# Article 66
# Total Characters: 13627
# Unique Characters: 2150
# Total Sequences: 13576
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_66.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_66.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_66.txt
#
# Article 67
# Total Characters: 13030
# Unique Characters: 1952
# Total Sequences: 12979
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_67.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_67.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_67.txt
#
# Article 68
# Total Characters: 15810
# Unique Characters: 2169
# Total Sequences: 15759
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_68.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_68.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_68.txt
#
# Article 69
# 1,. This is not an appropriate value
#
# 1,. This is not an appropriate value
#
# Total Characters: 16537
# Unique Characters: 2107
# Total Sequences: 16486
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_69.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_69.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_69.txt
#
# Article 70
# Total Characters: 13433
# Unique Characters: 1928
# Total Sequences: 13382
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_70.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_70.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_70.txt
#
# Article 71
# Total Characters: 13026
# Unique Characters: 1999
# Total Sequences: 12975
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_71.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_71.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_71.txt
#
# Article 72
# Total Characters: 10288
# Unique Characters: 1535
# Total Sequences: 10237
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_72.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_72.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_72.txt
#
# Article 73
# Total Characters: 14190
# Unique Characters: 2122
# Total Sequences: 14139
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_73.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_73.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_73.txt
#
# Article 74
# Total Characters: 13476
# Unique Characters: 1783
# Total Sequences: 13425
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_74.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_74.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_74.txt
#
# Article 75
# Total Characters: 15951
# Unique Characters: 2070
# Total Sequences: 15900
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_75.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_75.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_75.txt
#
# Article 76
# Total Characters: 12769
# Unique Characters: 1882
# Total Sequences: 12718
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_76.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_76.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_76.txt
#
# Article 77
# Total Characters: 17285
# Unique Characters: 2078
# Total Sequences: 17234
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_77.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_77.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_77.txt
#
# Article 78
# Total Characters: 1502
# Unique Characters: 555
# Total Sequences: 1451
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_78.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_78.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_78.txt
#
# Article 79
# Total Characters: 12422
# Unique Characters: 1896
# Total Sequences: 12371
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_79.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_79.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_79.txt
#
# Article 80
# Total Characters: 12321
# Unique Characters: 1689
# Total Sequences: 12270
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_80.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_80.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_80.txt
#
# Article 81
# Total Characters: 18439
# Unique Characters: 2242
# Total Sequences: 18388
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_81.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_81.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_81.txt
#
# Article 82
# 1.1. This is not an appropriate value
#
# Total Characters: 14344
# Unique Characters: 2021
# Total Sequences: 14293
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_82.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_82.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_82.txt
#
# Article 83
# Total Characters: 11434
# Unique Characters: 1509
# Total Sequences: 11383
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_83.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_83.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_83.txt
#
# Article 84
# 1,. This is not an appropriate value
#
# Total Characters: 15385
# Unique Characters: 2087
# Total Sequences: 15334
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_84.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_84.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_84.txt
#
# Article 85
# Total Characters: 13805
# Unique Characters: 2173
# Total Sequences: 13754
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_85.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_85.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_85.txt
#
# Article 86
# Total Characters: 14459
# Unique Characters: 1975
# Total Sequences: 14408
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_86.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_86.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_86.txt
#
# Article 87
# Total Characters: 13451
# Unique Characters: 2247
# Total Sequences: 13400
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_87.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_87.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_87.txt
#
# Article 88
# Total Characters: 11997
# Unique Characters: 1509
# Total Sequences: 11946
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_88.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_88.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_88.txt
#
# Article 89
# Total Characters: 12192
# Unique Characters: 1844
# Total Sequences: 12141
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_89.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_89.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_89.txt
#
# Article 90
# Total Characters: 12453
# Unique Characters: 1671
# Total Sequences: 12402
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_90.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_90.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_90.txt
#
# Article 91
# Total Characters: 15026
# Unique Characters: 2226
# Total Sequences: 14975
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_91.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_91.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_91.txt
#
# Article 92
# Total Characters: 12088
# Unique Characters: 2081
# Total Sequences: 12037
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_92.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_92.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_92.txt
#
# Article 93
# Total Characters: 14680
# Unique Characters: 2087
# Total Sequences: 14629
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_93.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_93.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_93.txt
#
# Article 94
# Total Characters: 11876
# Unique Characters: 1773
# Total Sequences: 11825
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_94.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_94.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_94.txt
#
# Article 95
# Total Characters: 15571
# Unique Characters: 1732
# Total Sequences: 15520
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_95.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_95.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_95.txt
#
# Article 96
# Total Characters: 11972
# Unique Characters: 1767
# Total Sequences: 11921
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_96.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_96.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_96.txt
#
# Article 97
# Total Characters: 17871
# Unique Characters: 2121
# Total Sequences: 17820
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_97.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_97.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_97.txt
#
# Article 98
# Total Characters: 13581
# Unique Characters: 2016
# Total Sequences: 13530
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_98.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_98.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_98.txt
#
# Article 99
# Total Characters: 11559
# Unique Characters: 1985
# Total Sequences: 11508
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_99.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_99.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_99.txt
#
# Article 100
# Total Characters: 12873
# Unique Characters: 1823
# Total Sequences: 12822
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_100.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_100.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_100.txt
#
# Article 101
# Total Characters: 12647
# Unique Characters: 1903
# Total Sequences: 12596
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_101.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_101.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_101.txt
#
# Article 102
# 8.. This is not an appropriate value
#
# Total Characters: 10638
# Unique Characters: 1837
# Total Sequences: 10587
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_102.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_102.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_102.txt
#
# Article 103
# Total Characters: 16254
# Unique Characters: 2259
# Total Sequences: 16203
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_103.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_103.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_103.txt
#
# Article 104
# Total Characters: 11814
# Unique Characters: 1620
# Total Sequences: 11763
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_104.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_104.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_104.txt
#
# Article 105
# Total Characters: 23141
# Unique Characters: 1908
# Total Sequences: 23090
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_105.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_105.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_105.txt
#
# Article 106
# Total Characters: 1744
# Unique Characters: 598
# Total Sequences: 1693
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\tokens_106.txt
# Tokens saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\vocab_106.txt
# Sequences saved to: E:\Documents\My Projects\Text Generation\data\Mindscape articles\seqs_106.txt
